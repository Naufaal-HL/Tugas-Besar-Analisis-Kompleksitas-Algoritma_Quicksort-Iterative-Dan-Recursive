# %% [markdown]
# <a href="https://colab.research.google.com/github/ShinyQ/Tugas-Besar-Analisis-Kompleksitas-Algoritma/blob/master/Kelompok_5_(Quick_Sort_%E2%80%93_Iterative_vs_Recursive).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tugas Besar Analisis Kompleksitas Algoritma**
#
# **Anggota kelompok :**
#
#
# *   Hanvito Michael Lee	(1301190090)
# *   Kurniadi Ahmad Wijaya	(1301194024)
# *   Naufal Haritsah Luthfi	(1301194073)
# *   Priyan Fadhil Supriyadi	(1301190442)
#
# <br>
#
# **Deskripsi :**
#
# Pada tugas besar ini kami akan melakukan analisis kompleksitas algoritma pada algoritma Quick Sort dengan proses atau prosesedur rekursif dan iterative. Untuk mengetahui tingkat efesiensi suatu algoritma menyangkut efesiensi kecepatan memori, digunakan suatu besaran waktu dan ruang, yaitu kompleksitas waktu ruang dari algoritma tersebut. Kompleksitas suatu algoritma sangat berguna untuk membanding-bandingkan beragam algoritma termasuk algoritma Quick Sort yang kami pilih. Sehingga dapat ditentukan algoritma yang paling efisien dari algoritma tersebut , serta algoritma yang tepat untuk digunakan untuk suatu kondisi.
#
# <br>
#
# **Ilustrasi Proses Sorting Algoritma Quick Sort:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Basic Operation Iterative Dan Recursive**
# Efisiensi suatu algoritma diukur dari berapa jumlah waktu dan ruang (space) memori yang dibutuhkan untuk menjalankannya,Kebutuhan waktu dan ruang suatu algoritma bergantung pada ukuran masukan (n), yang menyatakan jumlah data yang diproses, sehingga untuk mengetahui efisiensi waktu dari algoritma yang kita gunakan kita memilih basic operation sebagai berikut
# 1.   Membandingkan Array S[i] dengan *pivotitem* pada *partition*
# 2.   Input size = n

# %% [markdown]
# ![Program Quicksort Recursive.png](data:image/png;base64,...)

# %% [markdown]
# ![Program Quicksort Iterative 1.png](data:image/png;base64,...)

# %% [markdown]
# ![Program Quicksort Iterative 2 (1) 1.png](data:image/png;base64,...)

# %% [markdown]
# ## **Perhitungan Kompleksitas Waktu Iterative Dan Recursive**

# %% [markdown]
# ### **Worst Case Scenario Iterative Dan Recursive**
#
# Partisi yang paling tidak seimbang terjadi ketika salah satu sublist yang dikembalikan oleh rutin partisi berukuran n - 1 . Hal Ini dapat terjadi jika pivot menjadi elemen terkecil atau terbesar dalam daftar, atau dalam beberapa implementasi (misalnya, skema partisi Lomuto seperti dijelaskan di atas) ketika semua elemen sama.
#
# Jika ini terjadi berulang kali di setiap partisi, maka setiap panggilan rekursif memproses daftar yang ukurannya lebih kecil dari daftar sebelumnya. Akibatnya, kita bisa membuat n - 1 panggilan bersarang sebelum kita mencapai daftar ukuran 1. Ini berarti bahwa pohon panggilan adalah rantai linier dari n - 1 panggilan bersarang. panggilan ke-i melakukan O ( n - i ) pekerjaan yang harus dilakukan partisi, jadi dalam hal ini Quicksort memerlukan waktu O ( n ²) .

# %% [markdown]
# \begin{align}
# \\
# T(0) &= 0
# \\
# T(n) &= T(0) + T(n-1) + n-1
# \\
# T(n)  &= T(n-1) + n - 1
# \\
# T(n) - T(n-1) &= n - 1
# \\
# t_n - t_{n-1} &= n - 1
# \\
# t_n - t_{n-1} &= 1^n(n^1 - 1)
# \\
# \\
# (r-1)(r-1)^2 &= 0
# \\
# (r-1)^3 &= 0
# \\
# \\
# t_n &= C_11^n + C_2n1^n + C_3n^21^n
# \\ &= C_1 + C_2n + C_3n^2
# \\
# \\ t_1 &= t_0 + 1 - 1 = 0
# \\ t_2 &= t_1 + 2 - 1 = 1
# \\
# \\
# t_1 &= C_1 + 1C_2 + 1^2C_3
# \\ 0 &= C_1 + C_2 + C_3
# \\
# t_2 &= C_1 + 2C_2 + 2^2C_3
# \\
# 1 &= C_1 + 2C_2 + 4C_3
# \\
# \\ C_1 &= 0
# \\
# \\ 0 &= C_2 + C_3 (x2)
# \\ 1 &= 2C_2 + 4C_3 (x1)
# \\
# \\ 0 &= 2C_2 + 2C_3
# \\ 1 &= 2C_2 + 4C_3
#
# \\
# \\ -1 &= 2C_3
# \\ C_3 &= -1/2
# \\
#
# \\ 0 &= 2C_2 + 2 (-1/2)
# \\ 1 &= 2C_2
# \\ C_2 &= 1/2
# \\
#
# \\
# T(n) &= \frac{n(n-1)}{2}
# \\
# T(n) &= \frac{n^2 - n}{2} \in O(n^2)
# \end{align}

# %% [markdown]
# Kasus terburuk terjadi ketika array sudah diurutkan karena kita selalu memilih item pertama untuk item pivot. Oleh karena itu, jika kita memiliki alasan untuk percaya bahwa array hampir diurutkan, ini bukanlah pilihan yang baik untuk item pivot. Jika kita menggunakan metode ini, kasus terburuk tidak terjadi saat array sudah diurutkan. Tetapi kompleksitas waktu kasus terburuk masih n (n - 1) / 2.

# %% [markdown]
# ### **Best Case Scenario Iterative Dan Recursive**

# %% [markdown]
# Dalam kasus yang paling seimbang, setiap kali kami melakukan partisi, kami membagi daftar menjadi dua bagian yang hampir sama. Ini berarti setiap panggilan rekursif memproses daftar setengah ukuran. Akibatnya, kita hanya dapat membuat log2n panggilan bersarang sebelum kita mencapai daftar ukuran 1. Ini berarti kedalaman pohon panggilan adalah log2n . Tetapi tidak ada dua panggilan pada tingkat yang sama dari pohon panggilan yang memproses bagian yang sama dari daftar asli; dengan demikian, setiap level panggilan hanya membutuhkan O(n) waktu bersama-sama (setiap panggilan memiliki beberapa overhead konstan, tetapi karena hanya ada O(n) panggilan di setiap level, ini dimasukkan dalam O(n) faktor). Hasilnya adalah algoritma hanya menggunakan waktu O(nlogn) .

# %% [markdown]
# \begin{align}
# A(n) &= \sum_{p=1}^{n} \frac{1}{n} [A(p-1) + A(n-p)] + n - 1
# \\
# \displaystyle\sum_{p=1}^{n} [A(p-1) + A(n-p)] &= 2  \displaystyle\sum_{p=1}^{n} A(p-1)
# \\
# A(n) &= \frac{2}{n} \displaystyle\sum_{p=1}^{n} A(p-1) + n-1
# \\
# nA(n) &= 2\sum_{p=1}^{n}A(p-1)+n(n-1)
# \\
# (n-1)A(n-1) &= 2\sum_{p=1}^{n-1}A(p-1)+(n-1)(n-2)
# \\
# nA(n) - (n-1)A(n-1) &= 2A(n-1)+2(n-1)
# \\
# \frac{A(n)}{n+1} &= \frac{A(n-1)}{n} + \frac{2(n-1)}{n(n+1)}
# \\
# \\
# a_n &= \frac{A(n)}{n+1}
# \\
# a_n &= a_{n-1} + \frac{2(n-1)}{n(n+1)}
# \\
# a_0 &= 0
# \\
# t_n &= t_{n-1} + \frac{2}{n}
# \\
# t_1 &= 0
# \\
# t_n &= t_{n-1} + \frac{2}{n}
# \\
# t_{n-1} &= t_{n-2} + \frac{2}{n-1}
# \\
# t_{n-2} &= t_{n-3} + \frac{2}{n-2}
# \\
# t_2 &= t_1 + \frac{2}{2}
# \\
# t_1 &= 0
# \\
# t_n &= t_{n-1} + \frac{2}{n}
# \\
# &= t_{n-2} + \frac{2}{n-1} + \frac{2}{n}
# \\
# &= t_{n-3} + \frac{2}{n-2} + \frac{2}{n-1} + \frac{2}{n}
# \\
# &= t_1 + \frac{2}{2} + ... + \frac{2}{n-2} + \frac{2}{n-1} + \frac{2}{n}
# \\
# &= 0 + \frac{2}{2} + ... + \frac{2}{n-2} + \frac{2}{n-1} + \frac{2}{n}
# \\
# &= 2 \displaystyle\sum_{i=2}^{n} \frac{1}{i} \approx 2 ln n
# \end{align}

# %% [markdown]
# ## **Notasi Asimtotik Iterative Dan Recursive**

# %% [markdown]
# #### **Notasi Asimtotik Worst Case Scenario Iterative Dan Recursive**

# %% [markdown]
# \begin{align}
# T(n) = \frac{n^2 - n}{2} \in O(n^2)
# \\
# \\
# \end{align}

# %% [markdown]
# #### **Notasi Asimtotik Best Case Scenario Iterative Dan Recursive**

# %% [markdown]
# \begin{align}
# A(n) &\approx (n+1)2 ln n = (n+1)2(ln 2)(lg n)
# \\
# &\approx 1.38(n+1)lg n \in O(n lg n)
# \\
# \\
# \end{align}

# %% [markdown]
# ## **Class Efficiency Iterative Dan Recursive**

# %% [markdown]
# 1.   Class Efficiency Worst case : Quadratic
# 2.   Class Efficiency Best Case  : Linearithmic

# %% [markdown]
# ## **Modelling Analisis Kompleksitas Waktu Algoritma**

# %%
# Mengimport Library Yang Dibutuhkan
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd
import numpy as np
import timeit
import sys
import os

# Set Jumlah Limit Maksimal Proses Rekursif
sys.setrecursionlimit(4000)
os.makedirs('data', exist_ok=True)

# Mendefinisikan Function Calculate Untuk Perhitungan Waktu Algoritma
def calculate(fname, start):
    stop = timeit.default_timer()
    execution_time = stop - start
    return execution_time

# %%
# Algoritma Quick Sort Rekursif
def quick_sort_recursion(S):
  def partition(S, low, high):
      i = (low - 1)       
      pivot = S[high]    

      for j in range(low, high):

          if S[j] <= pivot:

              i += 1
              S[i], S[j] = S[j], S[i]

      S[i + 1], S[high] = S[high], S[i + 1]
      return (i + 1)

  def quickSort(S, low, high):
      if low < high:

          pi = partition(S, low, high)

          quickSort(S, low, pi-1)
          quickSort(S, pi + 1, high)
  
  n = len(S)
  quickSort(S, 0, n - 1)

# %%
# Algoritma Quick Sort Iteratif
def quick_sort_iterative(S):
    def partition(S, l, h):
        i = (l - 1)
        x = S[h]

        for j in range(l, h):
            if S[j] <= x:

                i = i+1
                S[i], S[j] = S[j], S[i]

        S[i+1], S[h] = S[h], S[i+1]
        return (i+1)

    def quickSortIterative(S, l, h):
        size = h - l + 1
        stack = [0] * (size)

        top = -1
        top = top + 1
        stack[top] = l
        top = top + 1
        stack[top] = h

        while top >= 0:
            h = stack[top]
            top = top - 1
            l = stack[top]
            top = top - 1

            p = partition(S, l, h)

            if p-1 > l:
                top = top + 1
                stack[top] = l
                top = top + 1
                stack[top] = p - 1

            if p+1 < h:
                top = top + 1
                stack[top] = p + 1
                top = top + 1
                stack[top] = h
  
    n = len(S)
    quickSortIterative(S, 0, n-1)

# %%
# Menggenerate Angka Untuk Test Kompleksitas 
# Terdiri Atas Data Random, Urut Ke Terkecil, Dan Nilai Yang Sama
size = [1000, 1500, 2000, 2500, 3000, 3500]

for n in size:
    array = list(np.random.randint(1, 5000,  n))
    name = 'rand' + str(n) + '.dat'
    np.savetxt('data/'+name, array, fmt=['%i'])

for x in size:
    number = []

    for n in range(x, 0, -1):
        number.append(n)

    name = 'reversed' + str(x) + '.dat'
    np.savetxt('data/'+name, number, fmt=['%i'])

for x in size:
    number = []
    for _ in range(x):
        number.append(5)

    name = 'equal' + str(x) + '.dat'
    np.savetxt('data/' + name, number, fmt=['%i'])

# %%
# Melakukan Proses Perhitungan Waktu Berdasarkan Masing-Masing Test Case
qs = []

# Perulangan Untuk Quicksort Recursive Dengan Data Random
for n in size:
    name = 'rand' + str(n) + '.dat'

    for _ in range(3):
      data = np.loadtxt('data/' + name)
      start = timeit.default_timer()
      quick_sort_recursion(data)  
      qs.append([n, calculate('Quicksort Recursive', start), 'Quicksort Recursive Random'])

# Perulangan Untuk Quicksort Iterative Data Random
for n in size:
    name = 'rand' + str(n) + '.dat'

    for _ in range(3):
      data = np.loadtxt('data/' + name)
      start = timeit.default_timer()
      quick_sort_iterative(data)  
      qs.append([n, calculate('Quicksort Iterative', start), 'Quicksort Iterative Random'])

# %%
# Perulangan Untuk Quicksort Recursive Data Sama
for n in size:
    name = 'equal' + str(n) + '.dat'

    for _ in range(3):
      data = np.loadtxt('data/' + name)
      start = timeit.default_timer()
      quick_sort_recursion(data)  
      qs.append([n, calculate('Quicksort Recursive', start), 'Quicksort Recursive Equal'])
      
# Perulangan Untuk Quicksort Iterative Data Sama
for n in size:
    name = 'equal' + str(n) + '.dat'
      
    for _ in range(3):
      data = np.loadtxt('data/' + name)
      start = timeit.default_timer()
      quick_sort_iterative(data)  
      qs.append([n, calculate('Quicksort Iterative', start), 'Quicksort Iterative Equal'])

# %%
# Perulangan Untuk Quicksort Recursive Data Terurut Mengecil
for n in size:
    name = 'reversed' + str(n) + '.dat'

    for _ in range(3):
      data = np.loadtxt('data/' + name)
      start = timeit.default_timer()
      quick_sort_recursion(data)  
      qs.append([n, calculate('Quicksort Recursive', start), 'Quicksort Recursive Reversed'])

# Perulangan Untuk Quicksort Iterative Data Terurut Mengecil
for n in size:
    name = 'reversed' + str(n) + '.dat'

    for _ in range(3):
      data = np.loadtxt('data/' + name)
      start = timeit.default_timer()
      quick_sort_iterative(data)  
      qs.append([n, calculate('Quicksort Iterative', start), 'Quicksort Iterative Reversed'])

# %%
# Membuat Data Array Menjadi Dataframe Untuk Dapat Diolah Lebih Lanjut
qs_np = np.array(qs)
data = pd.DataFrame({'Jumlah Data': qs_np[:, 0], 'Kompleksitas Waktu': qs_np[:, 1], 'Kategori': qs_np[:, 2]})

# %%
# Melakukan Konversi Dan Pembulatan Hasil Perhitungan Kompleksitas Waktu
def float_qs(x):
  return round(float(x), 3)

data['Kompleksitas Waktu'] = data['Kompleksitas Waktu'].apply(float_qs)

# %% [markdown]
# ##**Modelling Chart Dan Tabel**

# %%
# Memisahkan Data Berdasrkan Jenis Data Test Untuk Ditampilkan Pada Grafik
qs_random = data.loc[(data['Kategori'] == 'Quicksort Recursive Random') | (data['Kategori'] == 'Quicksort Iterative Random')]
qs_reversed = data.loc[(data['Kategori'] == 'Quicksort Recursive Reversed') | (data['Kategori'] == 'Quicksort Iterative Reversed')]  
qs_equal = data.loc[(data['Kategori'] == 'Quicksort Recursive Equal') | (data['Kategori'] == 'Quicksort Iterative Equal')]

# %%
# Melakukan Modelling Chart (Grafik) Sesuai Jenis Percobaan 
def line_qs_all():
    plt.figure(figsize=(15, 9))
    sns.set_context("notebook", rc={"lines.linewidth": 2.5})
    sns.set_style("whitegrid")
    sns.lineplot(data=data, x="Jumlah Data", y="Kompleksitas Waktu", hue='Kategori', marker="o", palette="deep", ci=None)

    plt.yticks(np.arange(0.02, 4.5, 0.2))
    plt.show()

def line_qs_random():
    plt.figure(figsize=(15, 8))
    sns.set_context("notebook", rc={"lines.linewidth": 2.5})
    sns.set_style("whitegrid")
    sns.lineplot(data=qs_random, x="Jumlah Data", y="Kompleksitas Waktu", hue='Kategori', marker="o", palette="deep", ci=None)

    plt.yticks(np.arange(0.003, 0.025, 0.002))
    plt.show()

def line_qs_equal():
    plt.figure(figsize=(15, 8))
    sns.set_context("notebook", rc={"lines.linewidth": 2.5})
    sns.set_style("whitegrid")
    sns.lineplot(data=qs_equal, x="Jumlah Data", y="Kompleksitas Waktu", hue='Kategori', marker="o", palette="deep", ci=None)

    plt.yticks(np.arange(0.2, 4.5, 0.2))
    plt.show()

def line_qs_reversed():
    plt.figure(figsize=(15, 8))
    sns.set_context("notebook", rc={"lines.linewidth": 2.5})
    sns.set_style("whitegrid")

    sns.lineplot(data=qs_reversed, x="Jumlah Data", y="Kompleksitas Waktu", hue='Kategori', marker="o", palette="deep", ci=None)

    plt.yticks(np.arange(0.2, 2.5, 0.2))
    plt.show()

# %%
# Memisahkan Data Berdasarkan Jenis Data Test Untuk Ditampilkan Pada Tabel
qs_reversed = qs_reversed.sort_values(by=['Jumlah Data', 'Kategori'])
qs_random = qs_random.sort_values(by=['Jumlah Data', 'Kategori'])
qs_equal = qs_equal.sort_values(by=['Jumlah Data', 'Kategori'])

# Mengubah Jenis Perhitungan Menjadi Array Untuk Diolah Perhitungan Kompleksitasnya
data_qs_reversed = [list(x) for x in qs_reversed.to_records(index=False)]
data_qs_random = [list(x) for x in qs_random.to_records(index=False)]
data_qs_equal = [list(x) for x in qs_equal.to_records(index=False)]

# %%
# Melakukan Perhitungan Rata-Rata Kompleksitas Waktu Dari Setiap Jenis Perhitungan
def sum_data(data_qs):
    def float_qs(x):
      return round(float(x), 3)

    qs_sum = []
    sum = 0
    c_jumlah = 0

    for n in data_qs:
        sum += n[1]
        c_jumlah += 1

        if c_jumlah == 3:
          qs_sum.append([n[0], float_qs(sum / 3), n[2]])
          sum = 0
          c_jumlah = 0
    
    return qs_sum

# Mengubah Data Menjadi Dataframe Untuk Disusun Pada Tabel Sesuai Jenis Perhitungan
def table_qs_sum(qs_sum):
    qs_sum = np.array(sum_data(qs_sum))
    qs_sum = pd.DataFrame({'Jumlah Data': qs_sum[:, 0], 'Rata-Rata Kompleksitas Waktu (s)': qs_sum[:, 1], 'Kategori': qs_sum[:, 2]})
    return qs_sum

# %% [markdown]
# ## **Kesimpulan**

# %% [markdown]
# ### **Grafik Quicksort Keseluruhan Data**
# Pada grafik garis dibawah ini kami mendapatkan kesimpulan pada Algoritma Quick Sort memiliki :
#
# <br>
#
# **Best Case:**
#
# Tingkat efisiensi kecepatan paling baik adalah algoritma Quick Sort Recursive dan algoritma Quick Sort Iterative dengan data yang random dengan kecepatan sekitar 0.02 Detik.
#
# <br>
#
# **Worse Case:**
#
# Posisi tercepat kedua kami mendapatkan Quick Sort Recursive dan algoritma Quick Sort Iterative dengan data yang terbalik atau descending dengan kecepatan sekitar 2 detik. Kemudian dalam riset yang kami lakukan, algoritma yang mempunyai tingkat efisiensi kecepatan paling rendah adalah algoritma Quick Sort Recursive dengan data yang sama/equal dan algoritma Quick Sort Iterative dengan data yang sama/equal dengan kecepatan sorting sekitar 3.22 detik.

# %%
line_qs_all()

# %% [markdown]
# ### **Grafik Quicksort Random Data**

# %% [markdown]
# Dari grafik dibawah dapat ditarik kesimpulan bahwa algoritma Quick Sort Iterative dengan data yang random cenderung sedikit lebih lambat di awal dibandingkan dengan algoritma Quick Sort Recursive dengan data random yang cenderung stabil namun keduanya berakhir dengan efisiensi kecepatan yang sama dan menjadikan test case ini sebagai best case pada algoritma Quick Sort.

# %%
table_qs_sum(data_qs_random)
# Out:
#    Jumlah Data Rata-Rata Kompleksitas Waktu (s)                    Kategori
# 0         1000                            0.005  Quicksort Iterative Random
# 1         1000                            0.005  Quicksort Recursive Random
# 2         1500                            0.007  Quicksort Iterative Random
# 3         1500                            0.007  Quicksort Recursive Random
# 4         2000                             0.01  Quicksort Iterative Random
# 5         2000                             0.01  Quicksort Recursive Random
# 6         2500                            0.014  Quicksort Iterative Random
# 7         2500                            0.013  Quicksort Recursive Random
# 8         3000                            0.015  Quicksort Iterative Random
# 9         3000                            0.016  Quicksort Recursive Random
# 10        3500                            0.019  Quicksort Iterative Random
# ...

# %%
line_qs_random()

# %% [markdown]
# ### **Grafik Quicksort Equal Data**

# %% [markdown]
# Pada grafik garis dibawah ini kami mendapatkan bahwa kedua algoritma baik Quick Sort Iterative dan algoritma Quick Sort Recursive dengan data yang sama/equal mempunyai tingkat efisiensi kecepatan yang sama. Data test ini merupakan data worst case paling pertama pada algoritma quick sort dimana semakin banyak data semakin lambat proses sorting dilakukan.

# %%
table_qs_sum(data_qs_equal)
# Out:
#    Jumlah Data Rata-Rata Kompleksitas Waktu (s)                   Kategori
# 0         1000                            0.265  Quicksort Iterative Equal
# 1         1000                            0.265  Quicksort Recursive Equal
# 2         1500                              0.6  Quicksort Iterative Equal
# 3         1500                            0.598  Quicksort Recursive Equal
# 4         2000                            1.093  Quicksort Iterative Equal
# 5         2000                             1.06  Quicksort Recursive Equal
# 6         2500                            1.713  Quicksort Iterative Equal
# 7         2500                            1.641  Quicksort Recursive Equal
# 8         3000                            2.431  Quicksort Iterative Equal
# 9         3000                            2.411  Quicksort Recursive Equal
# 10        3500                             3.35  Quicksort Iterative Equal
# ...

# %%
line_qs_equal()

# %% [markdown]
# ### **Grafik Quicksort Reversed Data**

# %% [markdown]
# Dapat dilihat pada Grafik garis dibawah algoritma Quick Sort Recursive sedikit lebih lambat dibandingkan dengan algoritma Quick Sort Iterative dengan data yang terbalik dari tujuan algoritma/reversed meskipun perbedaannya tidak begitu signifikan. Dan pada pengetesan ini menjadi worst case kedua setelah data yang equal (sama).

# %%
table_qs_sum(data_qs_reversed)
# Out:
#    Jumlah Data Rata-Rata Kompleksitas Waktu (s)                      Kategori
# 0         1000                             0.17  Quicksort Iterative Reversed
# 1         1000                            0.173  Quicksort Recursive Reversed
# 2         1500                            0.385  Quicksort Iterative Reversed
# 3         1500                            0.379  Quicksort Recursive Reversed
# 4         2000                            0.679  Quicksort Iterative Reversed
# 5         2000                            0.664  Quicksort Recursive Reversed
# 6         2500                             1.09  Quicksort Iterative Reversed
# 7         2500                            1.054  Quicksort Recursive Reversed
# 8         3000                            1.591  Quicksort Iterative Reversed
# 9         3000                            1.528  Quicksort Recursive Reversed
# 10        3500                            2.175  Quicksort Iterative Reversed
# ...

# %%
line_qs_reversed()
